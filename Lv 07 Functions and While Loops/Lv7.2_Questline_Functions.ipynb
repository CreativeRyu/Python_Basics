# %% [markdown]
# # **Lv 7 Questline Functions**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ***

# %%
# Funktionen die wir bereits verwendet haben
print("Hello")
numChar = len("Hello")
print(numChar)
print(len("Hello"))

# %%
def my_function():
    print("This is my first Python Function.")

# Funktionsaufruf
my_function()

# Funktionen müssen vor ihrem Aufruf definiert werden
# Funktionen dürfen nicht den gleichen Namen wie eine Varbiable haben

# %%
# Hello World als Function here
def hello_world():
    print("Hello World")

hello_world()
hello_world()
hello_world()

# %%
# Function from the picture without parameters and return
def addtwo(a, b):
    print(a+b)

addtwo(20, 80)

# %% [markdown]
# ## **Warum Funktionen ?**
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ***

# %% [markdown]
# [**Train Functions with Reeborg's World**](https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Alone&url=worlds%2Ftutorial_en%2Falone.json)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### **Lv 7.2 Quest 1 Fixed Hurdles**
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Funktionen erläutern
# 2. Ziel durch Funktionen erreichen lassen
# 3. Einen For Loop verwenden
# 4. Einen While Loop statt des For Loops einsetzen

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung Lv 7.2 Quest 1 Fixed Hurdles</b>
# </div>

# %%
# Lösung For Loop
for step in range(6):
    jump()

# Lösung While Loop
number_of_hurdles = 6
while number_of_hurdles > 0:
    jump()
    number_of_hurdles -= 1
    print(number_of_hurdles)

# %% [markdown]
# ***

# %% [markdown]
# #### **Lv 7.2 Quest 2 Random Number of Hurdles**
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Das Ziel erscheint zufällig auf der Karte.\
# Hier soll durch einen WhileLoop und der Bedingung *at_goal()* überprüft werden,\
# ob der Roboter bereits am Ziel angekommen ist.\
# Wenn das zutreffend ist, wird die Schleife verlassen und der Code beendet.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung Lv 7.2 Quest 2 Random Number of Hurdles</b>
# </div>

# %%
# Unterschiedliche Schreibweisen Bedingungen zu formulieren

while at_goal() != True:
    jump_over_hurdle()

while not at_goal():
    jump_over_hurdle()

# %% [markdown]
# ***

# %% [markdown]
# #### **Lv 7.2 Quest 3 Random Hurdles Position**
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Dieses mal sind es die Hürden die zufällig gesetzt werden.\
# Hier soll durch einen WhileLoop und der Bedingung *wall_in_front()* oder *front_is_clear()* überprüft werden,\
# ob der Roboter über eine Hürde springen muss.\
# Ist der Roboter am Ziel angekommen, wird der Code beendet.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung Lv 7.2 Quest 3 Random Hurdles Position</b>
# </div>

# %%
while at_goal() == False:
    if front_is_clear() == True:
        move()
    elif wall_in_front() == True:
        jump()

# %% [markdown]
# ***

# %% [markdown]
# #### **Lv 7.2 Quest 4 Random Hurdles Position and Hight**
# ![image.png](attachment:image.png)

# %% [markdown]
# Bei diesem Hürdenlauf werden die Hürden sowie deren Höhe zufällig gesetzt.\
# Durch WhileLoops soll geprüft werden ob der Roboter über eine Hürde\
# und wie hoch er dabei springen muss.\
# Der Code wird beendet, sobald der Roboter das Ziel erreicht hat.

# %% [markdown]
# ***

# %% [markdown]
# #### **Lv 7.2 Quest 5 Escape the Maze**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Optional Reeborg's World komplett durch spielen</b>
# </div>
