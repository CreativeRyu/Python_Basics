# %% [markdown]
# # **Level 5.2 Questline Lists**
#
#     https://docs.python.org/3/
#     https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# ## **List Toolbox**

# %%
fruits = []
fruits = ["Apple", "Cherry", "Lemon", "Melon"]
# Anzahl an Elementen in einer Liste
print(len(fruits))

# Indexing
print(fruits[2])
# print(fruits[4]) Wirft einen Fehler wenn Index nicht vorhanden
print(fruits[-1])

fruits[1] = "Sherry"
print(fruits)
fruits.append("Dragonfruit")
print(fruits)
fruits.extend(["Oranges", "Mango"])
print(fruits)

# Ein neues Element in die Liste integrieren
fruits.insert(1, "Pomegrenate")
print(fruits)

# Löschen eines Elementes aus einer Liste
print(len(fruits))
del fruits[1]
print(fruits)
print(len(fruits))

fruits.remove(fruits[1])
fruits.remove("Lemon")
print(fruits)

# Elemente in einer Liste tauschen
fruits[0], fruits[3] = fruits[3], fruits[0]
print(fruits)
# Out:
# 4
# Lemon
# Melon
# ['Apple', 'Sherry', 'Lemon', 'Melon']
# ['Apple', 'Sherry', 'Lemon', 'Melon', 'Dragonfruit']
# ['Apple', 'Sherry', 'Lemon', 'Melon', 'Dragonfruit', 'Oranges', 'Mango']
# ['Apple', 'Pomegrenate', 'Sherry', 'Lemon', 'Melon', 'Dragonfruit', 'Oranges', 'Mango']
# 8
# ['Apple', 'Sherry', 'Lemon', 'Melon', 'Dragonfruit', 'Oranges', 'Mango']
# 7
# ['Apple', 'Melon', 'Dragonfruit', 'Oranges', 'Mango']
# ['Oranges', 'Melon', 'Dragonfruit', 'Apple', 'Mango']

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# #### **Lv 5.2 Lists Training**
#
# This is an existing list of numbers hidden in the hat.\
# Step 1: write a line of code that prompts the user\
# to replace the middle number with an integer number entered by the user.\
# Step 2: write a line of code that removes the last element from the list.\
# Step 3: write a line of code that prints the length of the existing list.

# %%
hat_list = [1, 2, 3, 4, 5]

print(hat_list)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung Lv 5.2 Lists Training</b>
# </div>

# %%
hat_list = [1, 2, 3, 4, 5]

print(hat_list)
number = int(input("Tausche bitte die Ziffer in der Mitte der Liste mit einer beliebig ausgewählten Ziffer."))

hat_list[2] = number
print(hat_list)
hat_list.remove(hat_list[-1])
print(len(hat_list))
print(hat_list)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 42, 4, 5]
# 4
# [1, 2, 42, 4]

# %% [markdown]
# ***

# %% [markdown]
# #### **Lv 5.2 Quest 1 Names Roulette**
#
# Sie werden ein Programm schreiben, das einen zufälligen Namen aus einer Liste von\
# Namen auswählt.\
# Die ausgewählte Person muss die gesamte Rechnung für alle bezahlen.\
# Wichtig: Sie dürfen die Funktion choice() nicht verwenden.\
# names_string.split zerlegt die Zeichenkette names_string in einzelne Namen und stellt\
# sie in eine Liste mit dem Namen "names" zusammen.\
# Damit dies funktioniert, müssen Sie alle Namen als "names" gefolgt von einem Komma\
# und einem Leerzeichen eingeben. z.B. name, name, name

# %%
# Split string method
names_string = input("Give me everybody's names, separated by a comma. ")
names = names_string.split(", ")
# 🚨 Don't change the code above 👆

#Write your code below this line 👇

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung Lv 5.2 Quest 1 Names Roulette</b>
# </div>

# %%
# Split string method
names_string = input("Give me everybody's names, separated by a comma. ")
names = names_string.split(", ")
# 🚨 Don't change the code above 👆

import random
#Write your code below this line 👇
namesIndex = len(names)
randomNumber = random.randint(0, namesIndex-1)
print(names[randomNumber])

# %% [markdown]
# ### **PCEP Training**

# %%
list_1 = ["A", "B", "C"]
list_2 = list_1
list_3 = list_2

del list_1[0]
del list_2[0]
# Wie würde der Output aussehen
print(list_3)
# Out:
# ['B', 'C']

# %% [markdown]
# # **Nested Lists**

# %%
# Listen werden in eine neue Liste integriert
fruits = ["Strawberrys","Nectarines","Apples","Grapes","Peaches","Cherries","Pears"]
vegetables = ["Spinach","Broccoli","Tomatoes","Celery", "Potatoes"]

fallobst_salat = [fruits, vegetables]

print(fallobst_salat)
print(fallobst_salat[1][2])
# Out:
# [['Strawberrys', 'Nectarines', 'Apples', 'Grapes', 'Peaches', 'Cherries', 'Pears'], ['Spinach', 'Kale', 'Tomatoes', 'Celery', 'Potatoes']]
# Tomatoes

# %% [markdown]
# ***

# %% [markdown]
# #### **Lv 5.2 Quest 2 Treasure Map**
#
# ![image.png](attachment:image.png)
#
# You are going to write a program that will mark a spot with an X.\
# In the starting code, you will find a variable called map.\
# This map contains nested lists. When map is printed this is what the nested list looks like:\
# [['⬜️', '⬜️', '⬜️'],['⬜️', '⬜️', '⬜️'],['⬜️', '⬜️', '⬜️']]
#
# This is a bit hard to work with. We've used this line of code\
# print(f"{row1}\n{row2}\n{row3}") to format the 3 lists to be printed as a 3 by 3 square, each on a new line.
#
# Your job is to write a program that allows you to mark a square on the map using a two-digit system.\
# The first digit is the vertical location and the second digit is the horizontal location.\
# So an input of 23 should place an X at the position shown below:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
# 🚨 Don't change the code below 👇
row1 = ["⬜️","⬜️","⬜️"]
row2 = ["⬜️","⬜️","⬜️"]
row3 = ["⬜️","⬜️","⬜️"]
map = [row1, row2, row3]
print(f"{row1}\n{row2}\n{row3}")
position = input("Where do you want to put the treasure? ")
# 🚨 Don't change the code above 👆

#Write your code below this row 👇


#Write your code above this row 👆

# 🚨 Don't change the code below 👇
print(f"{row1}\n{row2}\n{row3}")
# Out:
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung Lv 5.2 Quest 3 Treasure Map</b>
# </div>

# %%
# 🚨 Don't change the code below 👇
row1 = ["⬜️","⬜️","⬜️"]
row2 = ["⬜️","⬜️","⬜️"]
row3 = ["⬜️","⬜️","⬜️"]
map = [row1, row2, row3]
print(f"{row1}\n{row2}\n{row3}")
position = input("Where do you want to put the treasure? ")
# 🚨 Don't change the code above 👆

# Write your code below this row 👇
xCoordinate = int(position[0])-1
yCoordinate = int(position[1])-1

map[yCoordinate][xCoordinate] = "X"

#Write your code above this row 👆

# 🚨 Don't change the code below 👇
print(f"{row1}\n{row2}\n{row3}")

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Project Rock Paper Scissors</b>
# </div>
