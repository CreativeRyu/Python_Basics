# %% [markdown]
# # **Lv 13.1 Questline Recursion**

# %%
def twist_numbers(number):
    if number > 7:
        number = number - 1
        number = twist_numbers(number)
        return number
    return number

print(twist_numbers(30))
# Out:
# 7

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)
